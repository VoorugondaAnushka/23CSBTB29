# %% [markdown]
# <a href="https://colab.research.google.com/github/VoorugondaAnushka/23CSBTB29/blob/main/Assignment4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
housing=pd.read_csv("Housing.csv")
print(housing.head())
housing.shape
housing.info()
housing.describe()
# Out:
#       price  area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 0  13300000  7420         4          2        3      yes        no       no
# 1  12250000  8960         4          4        4      yes        no       no
# 2  12250000  9960         3          2        2      yes        no      yes
# 3  12215000  7500         4          2        2      yes        no      yes
# 4  11410000  7420         4          1        2      yes       yes      yes
#
#   hotwaterheating airconditioning  parking prefarea furnishingstatus
# 0              no             yes        2      yes        furnished
# 1              no             yes        3       no        furnished
# 2              no              no        2      yes   semi-furnished
# 3              no             yes        3      yes        furnished
# 4              no             yes        2       no        furnished
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 545 entries, 0 to 544
# ...

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
housing=pd.read_csv("Housing.csv")
print(housing.head())
housing.isnull().sum()*100/housing.shape[0]
# Out:
#       price  area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 0  13300000  7420         4          2        3      yes        no       no
# 1  12250000  8960         4          4        4      yes        no       no
# 2  12250000  9960         3          2        2      yes        no      yes
# 3  12215000  7500         4          2        2      yes        no      yes
# 4  11410000  7420         4          1        2      yes       yes      yes
#
#   hotwaterheating airconditioning  parking prefarea furnishingstatus
# 0              no             yes        2      yes        furnished
# 1              no             yes        3       no        furnished
# 2              no              no        2      yes   semi-furnished
# 3              no             yes        3      yes        furnished
# 4              no             yes        2       no        furnished
# price               0.0
# area                0.0
# bedrooms            0.0
# ...

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
housing=pd.read_csv("Housing.csv")
print(housing.head())
fig, axs = plt.subplots(2,3, figsize = (10,5))
plt1 = sns.boxplot(housing['price'], ax = axs[0,0])
plt2 = sns.boxplot(housing['area'], ax = axs[0,1])
plt3 = sns.boxplot(housing['bedrooms'], ax = axs[0,2])
plt1 = sns.boxplot(housing['bathrooms'], ax = axs[1,0])
plt2 = sns.boxplot(housing['stories'], ax = axs[1,1])
plt3 = sns.boxplot(housing['parking'], ax = axs[1,2])

plt.tight_layout()
# Out:
#       price  area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 0  13300000  7420         4          2        3      yes        no       no
# 1  12250000  8960         4          4        4      yes        no       no
# 2  12250000  9960         3          2        2      yes        no      yes
# 3  12215000  7500         4          2        2      yes        no      yes
# 4  11410000  7420         4          1        2      yes       yes      yes
#
#   hotwaterheating airconditioning  parking prefarea furnishingstatus
# 0              no             yes        2      yes        furnished
# 1              no             yes        3       no        furnished
# 2              no              no        2      yes   semi-furnished
# 3              no             yes        3      yes        furnished
# 4              no             yes        2       no        furnished

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
housing=pd.read_csv("Housing.csv")
print(housing.head())
plt.boxplot(housing.price)
Q1 = housing.price.quantile(0.25)
Q3 = housing.price.quantile(0.75)
IQR = Q3 - Q1
housing = housing[(housing.price >= Q1 - 1.5*IQR) & (housing.price <= Q3 + 1.5*IQR)]
# Out:
#       price  area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 0  13300000  7420         4          2        3      yes        no       no
# 1  12250000  8960         4          4        4      yes        no       no
# 2  12250000  9960         3          2        2      yes        no      yes
# 3  12215000  7500         4          2        2      yes        no      yes
# 4  11410000  7420         4          1        2      yes       yes      yes
#
#   hotwaterheating airconditioning  parking prefarea furnishingstatus
# 0              no             yes        2      yes        furnished
# 1              no             yes        3       no        furnished
# 2              no              no        2      yes   semi-furnished
# 3              no             yes        3      yes        furnished
# 4              no             yes        2       no        furnished

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
housing=pd.read_csv("Housing.csv")
print(housing.head())
plt.boxplot(housing.area)
Q1 = housing.area.quantile(0.25)
Q3 = housing.area.quantile(0.75)
IQR = Q3 - Q1
housing = housing[(housing.area >= Q1 - 1.5*IQR) & (housing.area <= Q3 + 1.5*IQR)]
# Out:
#       price  area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 0  13300000  7420         4          2        3      yes        no       no
# 1  12250000  8960         4          4        4      yes        no       no
# 2  12250000  9960         3          2        2      yes        no      yes
# 3  12215000  7500         4          2        2      yes        no      yes
# 4  11410000  7420         4          1        2      yes       yes      yes
#
#   hotwaterheating airconditioning  parking prefarea furnishingstatus
# 0              no             yes        2      yes        furnished
# 1              no             yes        3       no        furnished
# 2              no              no        2      yes   semi-furnished
# 3              no             yes        3      yes        furnished
# 4              no             yes        2       no        furnished

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
housing=pd.read_csv("Housing.csv")
fig, axs = plt.subplots(2,3, figsize = (10,5))
plt1 = sns.boxplot(housing['price'], ax = axs[0,0])
plt2 = sns.boxplot(housing['area'], ax = axs[0,1])
plt3 = sns.boxplot(housing['bedrooms'], ax = axs[0,2])
plt1 = sns.boxplot(housing['bathrooms'], ax = axs[1,0])
plt2 = sns.boxplot(housing['stories'], ax = axs[1,1])
plt3 = sns.boxplot(housing['parking'], ax = axs[1,2])

plt.tight_layout()

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
housing=pd.read_csv("Housing.csv")
sns.pairplot(housing)
plt.show()

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
housing=pd.read_csv("Housing.csv")
plt.figure(figsize=(20, 12))
plt.subplot(2,3,1)
sns.boxplot(x = 'mainroad', y = 'price', data = housing)
plt.subplot(2,3,2)
sns.boxplot(x = 'guestroom', y = 'price', data = housing)
plt.subplot(2,3,3)
sns.boxplot(x = 'basement', y = 'price', data = housing)
plt.subplot(2,3,4)
sns.boxplot(x = 'hotwaterheating', y = 'price', data = housing)
plt.subplot(2,3,5)
sns.boxplot(x = 'airconditioning', y = 'price', data = housing)
plt.subplot(2,3,6)
sns.boxplot(x = 'furnishingstatus', y = 'price', data = housing)
plt.show()

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
housing=pd.read_csv("Housing.csv")
plt.figure(figsize = (10, 5))
sns.boxplot(x = 'furnishingstatus', y = 'price', hue = 'airconditioning', data = housing)
plt.show()

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
housing=pd.read_csv("Housing.csv")
varlist =  ['mainroad', 'guestroom', 'basement', 'hotwaterheating', 'airconditioning', 'prefarea']

# Defining the map function
def binary_map(x):
    return x.map({'yes': 1, "no": 0})

# Applying the function to the housing list
housing[varlist] = housing[varlist].apply(binary_map)

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
housing=pd.read_csv("Housing.csv")
housing.head()
# Out:
#       price  area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 0  13300000  7420         4          2        3      yes        no       no
# 1  12250000  8960         4          4        4      yes        no       no
# 2  12250000  9960         3          2        2      yes        no      yes
# 3  12215000  7500         4          2        2      yes        no      yes
# 4  11410000  7420         4          1        2      yes       yes      yes
#
#   hotwaterheating airconditioning  parking prefarea furnishingstatus
# 0              no             yes        2      yes        furnished
# 1              no             yes        3       no        furnished
# 2              no              no        2      yes   semi-furnished
# 3              no             yes        3      yes        furnished
# 4              no             yes        2       no        furnished

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
housing=pd.read_csv("Housing.csv")
status = pd.get_dummies(housing['furnishingstatus'])

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
housing=pd.read_csv("Housing.csv")
status.head()
# Out:
#    furnished  semi-furnished  unfurnished
# 0       True           False        False
# 1       True           False        False
# 2      False            True        False
# 3       True           False        False
# 4       True           False        False

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
housing=pd.read_csv("Housing.csv")
status = pd.get_dummies(housing['furnishingstatus'], drop_first = True)

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
housing=pd.read_csv("Housing.csv")
housing = pd.concat([housing, status], axis = 1)

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
housing=pd.read_csv("Housing.csv")
housing.head()
# Out:
#       price  area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 0  13300000  7420         4          2        3      yes        no       no
# 1  12250000  8960         4          4        4      yes        no       no
# 2  12250000  9960         3          2        2      yes        no      yes
# 3  12215000  7500         4          2        2      yes        no      yes
# 4  11410000  7420         4          1        2      yes       yes      yes
#
#   hotwaterheating airconditioning  parking prefarea furnishingstatus
# 0              no             yes        2      yes        furnished
# 1              no             yes        3       no        furnished
# 2              no              no        2      yes   semi-furnished
# 3              no             yes        3      yes        furnished
# 4              no             yes        2       no        furnished

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
housing=pd.read_csv("Housing.csv")
housing.drop(['furnishingstatus'], axis = 1, inplace = True)

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
housing=pd.read_csv("Housing.csv")
housing.head()
# Out:
#       price  area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 0  13300000  7420         4          2        3      yes        no       no
# 1  12250000  8960         4          4        4      yes        no       no
# 2  12250000  9960         3          2        2      yes        no      yes
# 3  12215000  7500         4          2        2      yes        no      yes
# 4  11410000  7420         4          1        2      yes       yes      yes
#
#   hotwaterheating airconditioning  parking prefarea furnishingstatus
# 0              no             yes        2      yes        furnished
# 1              no             yes        3       no        furnished
# 2              no              no        2      yes   semi-furnished
# 3              no             yes        3      yes        furnished
# 4              no             yes        2       no        furnished

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split # import the module containing train_test_split
import matplotlib.pyplot as plt
import seaborn as sns
housing=pd.read_csv("Housing.csv")
np.random.seed(0)
df_train, df_test = train_test_split(housing, train_size = 0.7, test_size = 0.3, random_state = 100)

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
housing=pd.read_csv("Housing.csv")
from sklearn.preprocessing import MinMaxScaler

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
housing=pd.read_csv("Housing.csv")
scaler = MinMaxScaler()

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
housing=pd.read_csv("Housing.csv")
num_vars = ['area', 'bedrooms', 'bathrooms', 'stories', 'parking','price']

df_train[num_vars] = scaler.fit_transform(df_train[num_vars])

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
housing=pd.read_csv("Housing.csv")
df_train.head()
# Out:
#         price      area  bedrooms  bathrooms   stories mainroad guestroom  \
# 359  0.169697  0.155227       0.4        0.0  0.000000      yes        no
# 19   0.615152  0.403379       0.4        0.5  0.333333      yes        no
# 159  0.321212  0.115628       0.4        0.5  0.000000      yes       yes
# 35   0.548133  0.454417       0.4        0.5  1.000000      yes        no
# 28   0.575758  0.538015       0.8        0.5  0.333333      yes        no
#
#     basement hotwaterheating airconditioning   parking prefarea  \
# 359       no              no              no  0.333333       no
# 19        no              no             yes  0.333333      yes
# 159      yes              no             yes  0.000000       no
# 35        no              no             yes  0.666667       no
# 28       yes             yes              no  0.666667       no
#
#     furnishingstatus
# 359      unfurnished
# 19    semi-furnished
# 159        furnished
# 35         furnished
# 28       unfurnished

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
housing=pd.read_csv("Housing.csv")
df_train.describe()
# Out:
#             price        area    bedrooms   bathrooms     stories     parking
# count  381.000000  381.000000  381.000000  381.000000  381.000000  381.000000
# mean     0.260333    0.288710    0.386352    0.136483    0.268591    0.242345
# std      0.157607    0.181420    0.147336    0.237325    0.295001    0.285933
# min      0.000000    0.000000    0.000000    0.000000    0.000000    0.000000
# 25%      0.151515    0.155227    0.200000    0.000000    0.000000    0.000000
# 50%      0.221212    0.234424    0.400000    0.000000    0.333333    0.000000
# 75%      0.345455    0.398099    0.400000    0.500000    0.333333    0.333333
# max      1.000000    1.000000    1.000000    1.000000    1.000000    1.000000

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
housing=pd.read_csv("Housing.csv")

# Convert 'yes' and 'no' to numerical values (1 and 0) in the relevant columns
for column in housing.columns:
    if housing[column].dtype == 'object':  # Check if the column has object (string) values
        housing[column] = housing[column].map({'yes': 1, 'no': 0})

plt.figure(figsize = (11, 10))
sns.heatmap(housing.corr(), annot = True, cmap="YlGnBu")
plt.show()

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
housing=pd.read_csv("Housing.csv")
y_train = df_train.pop('price')
X_train = df_train

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
housing=pd.read_csv("Housing.csv")
from sklearn.feature_selection import RFE
from sklearn.linear_model import LinearRegression

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
housing=pd.read_csv("Housing.csv")

# Convert 'yes' and 'no' to numerical values (1 and 0) in the relevant columns
for column in housing.columns:
    if housing[column].dtype == 'object':  # Check if the column has object (string) values
        housing[column] = housing[column].map({'yes': 1, 'no': 0})

# Create X_train and y_train from the processed housing data
y_train = housing.pop('price') # Assuming 'price' is the target variable
X_train = housing

# Impute missing values using the mean strategy
from sklearn.impute import SimpleImputer
imputer = SimpleImputer(strategy='mean') # Create an imputer object with the mean strategy
X_train_imputed = imputer.fit_transform(X_train) # Fit and transform the imputer on X_train

lm = LinearRegression()
lm.fit(X_train_imputed, y_train) # Use the imputed data for training the model
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/impute/_base.py:558: UserWarning: Skipping features without any observed values: ['furnishingstatus']. At least one non-missing value is needed for imputation with strategy='mean'.
#   warnings.warn(
# LinearRegression()

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.feature_selection import RFE # Import the RFE class
from sklearn.linear_model import LinearRegression # Import LinearRegression

housing=pd.read_csv("Housing.csv")

# Convert 'yes' and 'no' to numerical values (1 and 0) in the relevant columns
for column in housing.columns:
    if housing[column].dtype == 'object':  # Check if the column has object (string) values
        housing[column] = housing[column].map({'yes': 1, 'no': 0})

# Create X_train and y_train from the processed housing data
y_train = housing.pop('price') # Assuming 'price' is the target variable
X_train = housing

# Impute missing values using the mean strategy
from sklearn.impute import SimpleImputer
imputer = SimpleImputer(strategy='mean') # Create an imputer object with the mean strategy
X_train_imputed = imputer.fit_transform(X_train) # Fit and transform the imputer on X_train

lm = LinearRegression() # Define the LinearRegression object
lm.fit(X_train_imputed, y_train) # Use the imputed data for training the model

rfe = RFE(lm, n_features_to_select=6) # Instantiate RFE with the correct parameters
rfe = rfe.fit(X_train_imputed,y_train) # Use the imputed data for training the model
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/impute/_base.py:558: UserWarning: Skipping features without any observed values: ['furnishingstatus']. At least one non-missing value is needed for imputation with strategy='mean'.
#   warnings.warn(

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
housing=pd.read_csv("Housing.csv")
list(zip(X_train.columns,rfe.support_,rfe.ranking_))
# Out:
# [('area', False, 6),
#  ('bedrooms', False, 5),
#  ('bathrooms', True, 1),
#  ('stories', False, 3),
#  ('mainroad', True, 1),
#  ('guestroom', True, 1),
#  ('basement', False, 4),
#  ('hotwaterheating', True, 1),
#  ('airconditioning', True, 1),
#  ('parking', False, 2),
#  ('prefarea', True, 1)]

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

housing = pd.read_csv("Housing.csv")

# Convert 'yes' and 'no' to numerical values (1 and 0) in the relevant columns
for column in housing.columns:
    if housing[column].dtype == 'object':  # Check if the column has object (string) values
        housing[column] = housing[column].map({'yes': 1, 'no': 0})

# Create X_train and y_train from the processed housing data
y = housing.pop('price')  # Assuming 'price' is the target variable
X = housing

# Impute missing values using the mean strategy
from sklearn.impute import SimpleImputer
imputer = SimpleImputer(strategy='mean')  # Create an imputer object with the mean strategy
X_imputed = imputer.fit_transform(X)  # Fit and transform the imputer on X

# Split data into training and testing sets
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X_imputed, y, test_size=0.2, random_state=42)

lm = LinearRegression()
lm.fit(X_train, y_train)  # Use the imputed data for training the model

y_pred = lm.predict(X_test)

fig = plt.figure()
plt.scatter(y_test, y_pred)
fig.suptitle('y_test vs y_pred', fontsize=20)  # Plot heading
plt.xlabel('y_test', fontsize=18)  # X-label
plt.ylabel('y_pred', fontsize=16)  # Y-label
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/impute/_base.py:558: UserWarning: Skipping features without any observed values: ['furnishingstatus']. At least one non-missing value is needed for imputation with strategy='mean'.
#   warnings.warn(
# Text(0, 0.5, 'y_pred')

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
housing=pd.read_csv("Housing.csv")
from sklearn.metrics import r2_score
r2_score(y_test, y_pred)
# Out:
# 0.6437296086614116

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
housing=pd.read_csv("Housing.csv")

# Convert 'yes' and 'no' to numerical values (1 and 0) in the relevant columns
for column in housing.columns:
    if housing[column].dtype == 'object':  # Check if the column has object (string) values
        housing[column] = housing[column].map({'yes': 1, 'no': 0})

# Create X_train and y_train from the processed housing data
y_train = housing.pop('price') # Assuming 'price' is the target variable
X_train = housing

# Impute missing values using the mean strategy
from sklearn.impute import SimpleImputer
imputer = SimpleImputer(strategy='mean') # Create an imputer object with the mean strategy
X_train_imputed = imputer.fit_transform(X_train) # Fit and transform the imputer on X_train

lm = LinearRegression() # Define the LinearRegression object
lm.fit(X_train_imputed, y_train) # Use the imputed data for training the model

# Calculate residuals (assuming lm is your trained model)
res = y_train - lm.predict(X_train_imputed)

plt.scatter(y_train,res)
plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/impute/_base.py:558: UserWarning: Skipping features without any observed values: ['furnishingstatus']. At least one non-missing value is needed for imputation with strategy='mean'.
#   warnings.warn(

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
housing=pd.read_csv("Housing.csv")
fig = plt.figure()
sns.distplot((y_train - y_train), bins = 20) # Changed y_train_price to y_train
fig.suptitle('Error Terms', fontsize = 20)                  # Plot heading
plt.xlabel('Errors', fontsize = 18)
# Out:
# <ipython-input-36-a05c7fdad2e7>:7: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot((y_train - y_train), bins = 20) # Changed y_train_price to y_train
# /usr/local/lib/python3.10/dist-packages/seaborn/distributions.py:2496: UserWarning: Dataset has 0 variance; skipping density estimate. Pass `warn_singular=False` to disable this warning.
#   kdeplot(**{axis: a}, ax=ax, color=kde_color, **kde_kws)
# Text(0.5, 0, 'Errors')

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import statsmodels.api as sm # Import statsmodels
housing=pd.read_csv("Housing.csv")

# Assuming X_train_imputed and y_train are defined from your previous code
X_train_imputed = sm.add_constant(X_train_imputed) # Add a constant to the model
lm = sm.OLS(y_train, X_train_imputed).fit() # Use statsmodels OLS for the regression
print(lm.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                  price   R-squared:                       0.673
# Model:                            OLS   Adj. R-squared:                  0.666
# Method:                 Least Squares   F-statistic:                     99.81
# Date:                Tue, 10 Sep 2024   Prob (F-statistic):          1.01e-121
# Time:                        08:34:13   Log-Likelihood:                -8338.8
# No. Observations:                 545   AIC:                         1.670e+04
# Df Residuals:                     533   BIC:                         1.675e+04
# Df Model:                          11
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const      -2.831e+05   2.39e+05     -1.185      0.236   -7.52e+05    1.86e+05
# ...

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
housing=pd.read_csv("Housing.csv")
list(zip(X_train.columns,rfe.support_,rfe.ranking_))
# Out:
# [('area', False, 6),
#  ('bedrooms', False, 5),
#  ('bathrooms', True, 1),
#  ('stories', False, 3),
#  ('mainroad', True, 1),
#  ('guestroom', True, 1),
#  ('basement', False, 4),
#  ('hotwaterheating', True, 1),
#  ('airconditioning', True, 1),
#  ('parking', False, 2),
#  ('prefarea', True, 1)]
